# %% [markdown]
# # Guía 2 - Selección de atributos, revisión de sesgo y balanceo
#
# Este notebook plantilla acompaña la Guía 2. El objetivo es preparar un dataset más confiable antes del modelado, aplicando:
#
# - identificación de variable objetivo;
# - revisión de desbalance;
# - revisión de representatividad;
# - selección de atributos;
# - balanceo solo del conjunto de entrenamiento;
# - exportación de datasets finales.
#
# **Recordatorio de calidad:** Segmento es ordinal: Básico < Medio < Premium. Satisfacción también es ordinal: Baja < Media < Alta.

# %% [markdown]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# # IMPORTAR LIBRERIAS
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %%
import pandas as pd
# TODO: complete este bloque según la guía.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score    
from sklearn.impute import SimpleImputer

# %% [markdown]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# # CARGAR DATASET
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\HP\Desktop\EntregablesMayoH\2-Carpeta_Estudiantes_Guia2_Seleccion_Atributos_Sesgo_Balanceo\03_Notebook

# %%
import pandas as pd

df = pd.read_csv("../02_Datos/dataset_clientes_guia2_base.csv")

df.head()
# Out:
#   ID_Cliente  Edad  IngresoMensual  CantidadCompras  ComprasUltimos12M  \
# 0      C2000    18         1842000                2                  1
# 1      C2001    33         2326000                2                  4
# 2      C2002    48         5048000                8                  9
# 3      C2003    53         3641000                4                  5
# 4      C2004    48         2144000                4                  4
#
#    AntiguedadMeses  QuejasUltimos6M  DiasDesdeUltimaCompra  \
# 0               10                0                     36
# 1                7                0                     38
# 2               16                0                      6
# 3                7                1                     29
# 4               34                0                     42
#
#    VisitasWebUltimoMes  TiempoPromedioSesionMin  CuponesUsados        Ciudad  \
# 0                    0                      7.3              2        Bogotá
# 1                    5                      9.2              1  Barranquilla
# 2                    8                      8.0              0      Medellín
# 3                    4                      5.7              1          Cali
# 4                    2                      8.3              4          Cali
#
#    CanalPreferido ZonaResidencia Segmento Satisfaccion CodigoCampania  \
# 0   Tienda física          Rural   Básico         Alta              B
# 1             Web         Urbana   Básico        Media              A
# 2        Referido         Urbana    Medio         Alta              A
# 3   Tienda física         Urbana    Medio         Baja              D
# 4  Redes sociales          Rural   Básico         Alta              B
#
#    Abandono
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# 2. Diagnóstico inicial
# TODO: complete este bloque según la guía.
print(df. shape)
# Out:
# (360, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID_Cliente               360 non-null    str
#  1   Edad                     360 non-null    int64
#  2   IngresoMensual           360 non-null    int64
#  3   CantidadCompras          360 non-null    int64
#  4   ComprasUltimos12M        360 non-null    int64
#  5   AntiguedadMeses          360 non-null    int64
#  6   QuejasUltimos6M          360 non-null    int64
#  7   DiasDesdeUltimaCompra    360 non-null    int64
#  8   VisitasWebUltimoMes      360 non-null    int64
#  9   TiempoPromedioSesionMin  360 non-null    float64
#  10  CuponesUsados            360 non-null    int64
#  11  Ciudad                   360 non-null    str
#  12  CanalPreferido           360 non-null    str
#  13  ZonaResidencia           360 non-null    str
#  14  Segmento                 360 non-null    str
#  15  Satisfaccion             360 non-null    str
#  16  CodigoCampania           360 non-null    str
#  17  Abandono                 360 non-null    int64
# dtypes: float64(1), int64(10), str(7)
# memory usage: 50.8 KB

# %%
df.describe(include = 'all')
# Out:
#        ID_Cliente        Edad  IngresoMensual  CantidadCompras  \
# count         360  360.000000    3.600000e+02       360.000000
# unique        360         NaN             NaN              NaN
# top         C2000         NaN             NaN              NaN
# freq            1         NaN             NaN              NaN
# mean          NaN   36.119444    3.318497e+06         5.436111
# std           NaN    9.976555    1.627261e+06         3.586003
# min           NaN   18.000000    9.000000e+05         0.000000
# 25%           NaN   28.000000    2.182750e+06         3.000000
# 50%           NaN   36.000000    3.011000e+06         5.000000
# 75%           NaN   42.250000    4.026250e+06         8.000000
# max           NaN   68.000000    9.800000e+06        22.000000
#
#         ComprasUltimos12M  AntiguedadMeses  QuejasUltimos6M  \
# count          360.000000       360.000000       360.000000
# unique                NaN              NaN              NaN
# top                   NaN              NaN              NaN
# freq                  NaN              NaN              NaN
# mean             5.394444        26.191667         0.836111
# std              3.787529        15.002672         1.098658
# min              0.000000         3.000000         0.000000
# 25%              3.000000        15.000000         0.000000
# 50%              5.000000        23.000000         0.500000
# 75%              8.000000        33.250000         1.000000
# max             22.000000        83.000000         5.000000
#
#         DiasDesdeUltimaCompra  VisitasWebUltimoMes  TiempoPromedioSesionMin  \
# count              360.000000           360.000000               360.000000
# unique                    NaN                  NaN                      NaN
# top                       NaN                  NaN                      NaN
# freq                      NaN                  NaN                      NaN
# mean                40.441667             5.227778                 7.629167
# std                 26.046817             3.040727                 2.647111
# min                  1.000000             0.000000                 1.000000
# 25%                 21.000000             3.000000                 5.900000
# 50%                 36.000000             5.000000                 7.700000
# 75%                 54.250000             7.000000                 9.300000
# max                151.000000            16.000000                15.300000
#
#         CuponesUsados  Ciudad CanalPreferido ZonaResidencia Segmento  \
# count      360.000000     360            360            360      360
# unique            NaN       5              4              3        3
# top               NaN  Bogotá            Web         Urbana   Básico
# freq              NaN      96            126            238      178
# mean         2.152778     NaN            NaN            NaN      NaN
# std          1.628949     NaN            NaN            NaN      NaN
# min          0.000000     NaN            NaN            NaN      NaN
# 25%          1.000000     NaN            NaN            NaN      NaN
# 50%          2.000000     NaN            NaN            NaN      NaN
# 75%          3.000000     NaN            NaN            NaN      NaN
# max          8.000000     NaN            NaN            NaN      NaN
#
#        Satisfaccion CodigoCampania    Abandono
# count           360            360  360.000000
# unique            3              6         NaN
# top           Media              D         NaN
# freq            176             79         NaN
# mean            NaN            NaN    0.255556
# std             NaN            NaN    0.436780
# min             NaN            NaN    0.000000
# 25%             NaN            NaN    0.000000
# 50%             NaN            NaN    0.000000
# 75%             NaN            NaN    1.000000
# max             NaN            NaN    1.000000

# %%
df.columns
# Out:
# Index(['ID_Cliente', 'Edad', 'IngresoMensual', 'CantidadCompras',
#        'ComprasUltimos12M', 'AntiguedadMeses', 'QuejasUltimos6M',
#        'DiasDesdeUltimaCompra', 'VisitasWebUltimoMes',
#        'TiempoPromedioSesionMin', 'CuponesUsados', 'Ciudad', 'CanalPreferido',
#        'ZonaResidencia', 'Segmento', 'Satisfaccion', 'CodigoCampania',
#        'Abandono'],
#       dtype='str')

# %%
#Confirmar la variable objetivo

df['Abandono'].value_counts()
# Out:
# Abandono
# 0    268
# 1     92
# Name: count, dtype: int64

# %% [markdown]
# # DETECTAR AUTOMATICAMENTE VARIABLES NUMÉRICAS Y CATEGÓRICAS

# %%
#Filtrar columnas
columnas_numericas = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
columnas_categoricas = df.select_dtypes(include=['str']).columns.tolist()
print("columnas numericas:", columnas_numericas)
print("columnas categoricas:", columnas_categoricas)
# Out:
# columnas numericas: ['Edad', 'IngresoMensual', 'CantidadCompras', 'ComprasUltimos12M', 'AntiguedadMeses', 'QuejasUltimos6M', 'DiasDesdeUltimaCompra', 'VisitasWebUltimoMes', 'TiempoPromedioSesionMin', 'CuponesUsados', 'Abandono']
# columnas categoricas: ['ID_Cliente', 'Ciudad', 'CanalPreferido', 'ZonaResidencia', 'Segmento', 'Satisfaccion', 'CodigoCampania']

# %% [markdown]
# # MEDIR CARDINALIDAD
# Medimos cardinalidad para indicar cuantos valores únicos tiene una variable categórica, esto nos ayuda a decidir la codificación: Si encontramos baja cardinalidad utilizamos el OneHotEncode, si encontramos alta cardinalidad no podemos utilizar el OneHotEncoder porque es posible que cree demasiadas columnas. la idea es optimizar espacio en disco.

# %%
cardinalidad = df[columnas_categoricas].nunique().sort_values(ascending=False)
cardinalidad
# Out:
# ID_Cliente        360
# CodigoCampania      6
# Ciudad              5
# CanalPreferido      4
# ZonaResidencia      3
# Segmento            3
# Satisfaccion        3
# dtype: int64

# %%
#Clasificamos las variables 
variable_objetivo = 'Abandono'
columna_excluir = ['ID_Cliente']
columnas_numericas = ["Edad"]

# %%
# Clasificación de variables

## Variable identificadora
- ID_Cliente

## Variable objetivo
- Abandono

## Variables numéricas discretas
- Edad
- CantidadCompras
- ComprasUltimos12M
- AntiguedadMeses
- QuejasUltimos6M
- DiasDesdeUltimaCompra
- VisitasWebUltimoMes
- CuponesUsados

## Variables numéricas continuas
- IngresoMensual
- TiempoPromedioSesionMin

## Variables categóricas nominales
- Ciudad
- CanalPreferido
- ZonaResidencia
- CodigoCampania

## Variables categóricas ordinales
- Segmento
- Satisfaccion
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Clasificación de variables
#       2
#       3 ## Variable identificadora
# ----> 4 - ID_Cliente
#       5
#       6 ## Variable objetivo
#       7 - Abandono
#
# NameError: name 'ID_Cliente' is not defined

# %%
# 3. Variable objetivo y desbalance
# TODO: complete este bloque según la guía.

# %%
# 4. Clasificación técnica de variables
# TODO: complete este bloque según la guía.

# %%
# 5. Revisión de representatividad por zona
# TODO: complete este bloque según la guía.

# %%
# 6. Separación entrenamiento/prueba estratificada
# TODO: complete este bloque según la guía.

# %%
# 7. Preprocesamiento sin fuga de información
# TODO: complete este bloque según la guía.

# %%
# 8. Revisión de baja variabilidad
# TODO: complete este bloque según la guía.

# %%
# 9. Revisión de correlación entre variables numéricas
# TODO: complete este bloque según la guía.

# %%
# 10. Método de filtro: F-score
# TODO: complete este bloque según la guía.

# %%
# 11. Método integrado: importancia con Random Forest
# TODO: complete este bloque según la guía.

# %%
# 12. Selección final de atributos
# TODO: complete este bloque según la guía.

# %%
# 13. Construir dataset seleccionado
# TODO: complete este bloque según la guía.

# %%
# 14. Balanceo solo del conjunto de entrenamiento
# TODO: complete este bloque según la guía.

# %%
# 15. Verificación rápida con modelo básico
# TODO: complete este bloque según la guía.

# %%
# 16. Exportar entregables
# TODO: complete este bloque según la guía.
