# %% [markdown]
# Importamos librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)

# %% [markdown]
# #**Cremos el Dataset**

# %%
df_actividad = pd.DataFrame({
    "ClienteID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Edad": [21, 25, 34, 45, 52, 23, 40, 37, 29, 60],
    "IngresoMensual": [900, 1500, 2800, 4200, 5200, 1100, 3900, 3100, 2000, 10000],
    "Deuda": [200, 500, 1200, 1800, 2500, 300, 1600, 900, 700, 15000],
    "AntiguedadMeses": [3, 8, 24, 36, 48, 5, 30, 20, 12, 60],
    "Ciudad": ["Bogotá", "Cali", "Medellín", "Bogotá", "Cali", "Cartagena", "Medellín", "Bogotá", "Cartagena", "Cali"],
    "Riesgo": [0, 0, 1, 1, 1, 0, 1, 0, 0, 1]
})

df_actividad
# Out:
#    ClienteID  Edad  IngresoMensual  Deuda  AntiguedadMeses     Ciudad  Riesgo
# 0        101    21             900    200                3     Bogotá       0
# 1        102    25            1500    500                8       Cali       0
# 2        103    34            2800   1200               24   Medellín       1
# 3        104    45            4200   1800               36     Bogotá       1
# 4        105    52            5200   2500               48       Cali       1
# 5        106    23            1100    300                5  Cartagena       0
# 6        107    40            3900   1600               30   Medellín       1
# 7        108    37            3100    900               20     Bogotá       0
# 8        109    29            2000    700               12  Cartagena       0
# 9        110    60           10000  15000               60       Cali       1

# %%
df_actividad.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ClienteID        10 non-null     int64
#  1   Edad             10 non-null     int64
#  2   IngresoMensual   10 non-null     int64
#  3   Deuda            10 non-null     int64
#  4   AntiguedadMeses  10 non-null     int64
#  5   Ciudad           10 non-null     str
#  6   Riesgo           10 non-null     int64
# dtypes: int64(6), str(1)
# memory usage: 692.0 bytes

# %% [markdown]
# #**Descripción del dtaset**
# Es un dataset que describe la informacion de cada cliente de un banco o isntitución financiera, en donmde describe en nombre del cliente, la edad, el ingresoMensual, la ciudad de residencia, la antiguedad y el riesgo.

# %% [markdown]
# #**Diagnóstico inicial del dataset**
# Antes de codificar identificamos que tipo de datos tenmos, para ello ejecutamos el codigo df. dtypes.

# %%
df_actividad.dtypes
# Out:
# ClienteID          int64
# Edad               int64
# IngresoMensual     int64
# Deuda              int64
# AntiguedadMeses    int64
# Ciudad               str
# Riesgo             int64
# dtype: object

# %% [markdown]
# #**Interpretación del resultado**
# 1.`int64` indican variables numéricas.
# 2.`Ciudad` aparecen como str. que para pandas es el "object"
#
# #**Ojo pedagógico**
# Que una columna aparezca como `object`u str **no significa automáticamente** que deba codificarse igual.
# Primero debemos entender su naturaleza:
# 1. `Ciudad`: nominal

# %% [markdown]
# **Separamos las columnas por tipo tecnico de datos.**

# %%
columnas_numericas = df_actividad.select_dtypes(include=["int64", "float64"]).columns.tolist()
columnas_categoricas = df_actividad.select_dtypes(include=["str"]).columns.tolist()

print("Columnas numéricas:", columnas_numericas)
print("Columnas categóricas:", columnas_categoricas)
# Out:
# Columnas numéricas: ['ClienteID', 'Edad', 'IngresoMensual', 'Deuda', 'AntiguedadMeses', 'Riesgo']
# Columnas categóricas: ['Ciudad']

# %% [markdown]
# #**One-HotEncoding**
# Lo utilizamos para realizar la codificación binaria.

# %%
df_actividad_nehot = pd.get_dummies(df, columns=["Ciudad"], dtype=int)
df_actividad_onehot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_actividad_nehot = pd.get_dummies(df, columns=["Ciudad"], dtype=int)
#       2 df_actividad_onehot
#
# NameError: name 'df' is not defined
